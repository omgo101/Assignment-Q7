# %%
#importing pandas library for data handling and manipulation
import pandas as pd 
#importing numpy for scientific calculation 
import numpy as np
#importing pyplot module from matplotlib for data visualization including seaborn as sns 
import matplotlib.pyplot as plt
from scipy. stats import skew #function for skewness
from scipy.stats import kurtosis #fuction for kurtosis

# %%
from google.colab import drive #import drive for csv file 
drive.mount('/content/drive', force_remount=True) 
data = pd.read_csv("/content/Q9_a.csv") # reading path of csv file
# Out:
# Mounted at /content/drive

# %%
data #displaying table
# Out:
#     Index  speed  dist
# 0       1      4     2
# 1       2      4    10
# 2       3      7     4
# 3       4      7    22
# 4       5      8    16
# 5       6      9    10
# 6       7     10    18
# 7       8     10    26
# 8       9     10    34
# 9      10     11    17
# 10     11     11    28
# 11     12     12    14
# 12     13     12    20
# 13     14     12    24
# 14     15     12    28
# 15     16     13    26
# 16     17     13    34
# 17     18     13    34
# 18     19     13    46
# 19     20     14    26
# 20     21     14    36
# 21     22     14    60
# 22     23     14    80
# 23     24     15    20
# 24     25     15    26
# 25     26     15    54
# 26     27     16    32
# 27     28     16    40
# 28     29     17    32
# 29     30     17    40
# 30     31     17    50
# 31     32     18    42
# 32     33     18    56
# 33     34     18    76
# 34     35     18    84
# 35     36     19    36
# 36     37     19    46
# 37     38     19    68
# 38     39     20    32
# ...

# %%
data2 = data[['speed', 'dist']] #storing only 2nd and 3rd column because we dont use index column
data2 #displaying table
# Out:
#     speed  dist
# 0       4     2
# 1       4    10
# 2       7     4
# 3       7    22
# 4       8    16
# 5       9    10
# 6      10    18
# 7      10    26
# 8      10    34
# 9      11    17
# 10     11    28
# 11     12    14
# 12     12    20
# 13     12    24
# 14     12    28
# 15     13    26
# 16     13    34
# 17     13    34
# 18     13    46
# 19     14    26
# 20     14    36
# 21     14    60
# 22     14    80
# 23     15    20
# 24     15    26
# 25     15    54
# 26     16    32
# 27     16    40
# 28     17    32
# 29     17    40
# 30     17    50
# 31     18    42
# 32     18    56
# 33     18    76
# 34     18    84
# 35     19    36
# 36     19    46
# 37     19    68
# 38     20    32
# 39     20    48
# 40     20    52
# 41     20    56
# 42     20    64
# 43     22    66
# 44     23    54
# 45     24    70
# 46     24    92
# 47     24    93
# 48     24   120
# 49     25    85

# %%
data2.skew(axis = 0)
# Out:
# speed   -0.117510
# dist     0.806895
# dtype: float64

# %%
data2.kurtosis(axis=0)
# Out:
# speed   -0.508994
# dist     0.405053
# dtype: float64

# %%
f,ax=plt.subplots(figsize=(15,5))
plt.subplot(1,2,1) #the figure has 1 row, 2 columns, and this plot is the first plot.
plt.boxplot(data2.speed)
plt.title('speed')
plt.subplot(1,2,2) #the figure has 1 row, 2 columns, and this plot is the second plot.
plt.boxplot(data.dist)
plt.title('dist')
# Out:
# Text(0.5, 1.0, 'dist')
